# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd

# %%
def sir(total_pop, beta, gamma):
    """
    beta - infection rate
    gamma - recovery rate
    S = susceptable
    I = infected
    R = recovered 
    """
    I = 200
    S = total_pop - I
    R = 0
    t = 0
    ss = []
    ii = []
    rr = []
    nc = []
    while t < 100:
        ss += [S]
        ii += [I]
        rr += [R]
        
        new_r = gamma * I 
        new_i = beta * S * I
        nc += [new_i]
        R = R + new_r
        I = I + new_i - new_r
        S = S - new_i
        
        t += 1
    return ss, ii, rr, nc

# %%
def sir_beta(total_pop, initial_beta, gamma, k):
    """
    beta - infection rate per day
    gamma - inverse infection period
    S = susceptable
    I = infected
    R = recovered
    t = time in days
    d = deaths
    k = public sensitivity to deaths (as measured RE 1918 flu pandemic in http://refhub.elsevier.com/S1201-9712(20)30117-X/sbref0015)
    fat = fatality rate
    sev = severe illness rate
    """
    I = 1
    S = total_pop - I
    R = 0
    t = 0
    d = 32
    ss = []
    ii = []
    bbs = []
    rr = []
    nc = []
    fat = 0.025
    sev = 0.2
    sps = 2* sp.Close.values[-len(cases):] / sp.Close.values.max()
    def beta_f():
        sp_factor = sps[t] if t < len(sps) else sps[-1]
        return sp_factor * initial_beta * math.pow((1 - (R * 0.02) / 10000000), k) * (1-t/1000) + 0.1 * (t/1000)
    
    while t < 150:
        ss += [S]
        ii += [I]
        rr += [R]
        d = R * fat
        c = R * sev
        beta = beta_f()
        bbs.append(beta)
        new_r = gamma * I 
        new_i = beta * S * I / total_pop
        nc += [new_i]
        S = S - new_i
        I = I + new_i - new_r
        R = R + new_r
        t += 1
    return ss, ii, rr, bbs, nc

# %%
cases = [0.000001,0.00001,1,0.00001,1,0.00001,3,1,1,3,2,0.00001,0.00001,5,10,6,7,11,14,13,34,16,30,19,40,40,53,51,48,58,74,43,79,46,50,15,2,0.00001]

# %%
infection_time = 5
sp = pd.read_csv("~/Downloads/^GSPC.csv")


inverse_time = 1 / infection_time 
s, i, r, b, n = sir_beta(350000000, 0.4, inverse_time, 1300)
t = range(0, 150)

plt.plot(t, i, label='infected')
plt.plot(t, np.array(n), '--', label='new cases')
plt.scatter(t[:len(cases) - 7], cases[:-7], marker='.', c='k')
plt.scatter(t[len(cases) - 7: len(cases)], cases[-7:], marker='x', c='r')
plt.legend()
plt.ylim(bottom=1)  

plt.yscale('log')
plt.show()


plt.plot(t[:len(cases)], sp.Close.values[-len(cases):] / 3000)
print("peak infected patients of {0} on day {1}".format(int(max(i)), np.argmax(i)))
print("peak new cases of {0} on day {1}".format(int(max(n)), np.argmax(n)))
print("{}% of population was infected at one point by day {}".format(max(r) / (float(s[0] + i[0] + r[0])) * 100, len(r)) )
print("{} people die by day {} (assuming 2% fatality rate)".format( int(max(r) * 0.02), len(r)))
plt.plot(t, b, label='expected transmissions per person, per day')
plt.legend()
plt.show()
# Out:
# peak infected patients of 40292 on day 98
# peak new cases of 8379 on day 94
# 0.10032920554771384% of population was infected at one point by day 150
# 7023 people die by day 150 (assuming 2% fatality rate)

# %%
s, i, r = sir(8500000, (1 / 8500000.0) * 0.5, 0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-348-1ddb95768bb2> in <module>
# ----> 1 s, i, r = sir(8500000, (1 / 8500000.0) * 0.5, 0.2)
#
# ValueError: too many values to unpack (expected 3)

# %%
t = range(0, 100)
plt.plot(t, s, label='susceptable')
plt.plot(t, i, label='infected')
plt.plot(t, r, label='recovered')
plt.legend()
plt.show()
print("peak infections of {0} at day {1}".format(int(max(i)), np.argmax(i)))
print("{}% of population was infected at one point by day {}".format(max(r) / (float(s[0] + i[0] + r[0])) * 100, len(r)) )
print("{} people die by day 100 (assuming 2% fatality rate)".format( int(max(r) * 0.02)))
# Out:
# peak infections of 1368064 at day 57
# 80.5483501042871% of population was infected at one point by day 100
# 136932 people die by day 100 (assuming 2% fatality rate)

# %%
# Out:
# peak infections of 30861018.642755907 at day 21
