# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
def sir(total_pop, beta, gamma):
    """
    beta - infection rate
    gamma - recovery rate
    S = susceptable
    I = infected
    R = recovered 
    """
    I = 200
    S = total_pop - I
    R = 0
    t = 0
    ss = []
    ii = []
    rr = []
    
    while t < 100:
        ss += [S]
        ii += [I]
        rr += [R]
        S = S - beta * S * I / total_pop
        I = I + beta * S * I / total_pop - gamma * I
        R = R + gamma * I
        t += 1
    return ss, ii, rr

# %%
def sir_beta(total_pop, initial_beta, gamma, k):
    """
    beta - infection rate per day
    gamma - inverse infection period
    S = susceptable
    I = infected
    R = recovered
    t = time in days
    d = deaths
    k = public sensitivity to deaths (as measured RE 1918 flu pandemic in http://refhub.elsevier.com/S1201-9712(20)30117-X/sbref0015)
    fat = fatality rate
    sev = severe illness rate
    """
    I = 1000
    S = total_pop - I
    R = 0
    t = 0
    d = 32
    ss = []
    ii = []
    bbs = []
    rr = []
    fat = 0.025
    sev = 0.2
    
    def beta_f():
        return initial_beta * math.pow((1 - R / total_pop), k) + 0
    
    while t < 100:
        ss += [S]
        ii += [I]
        rr += [R]
        d = R * fat
        c = R * sev
        beta = beta_f()
        bbs.append(beta)
        S = S - beta * S * I / total_pop
        I = I + beta * S * I / total_pop - gamma * I
        R = R + gamma * I
        t += 1
    return ss, ii, rr, bbs

# %%
s, i, r, b = sir_beta(9000000, 0.3, 0.14, 1000)
t = range(0, 100)
plt.plot(t, i, label='infected')
plt.plot(t, r, label='recovered')
plt.legend()
plt.show()
print("peak infections of {0} at day {1}".format(max(i), np.argmax(i)))
plt.plot(t, b)
plt.show()
# Out:
# peak infections of 4335.95552638217 at day 17

# %%
s, i, r = sir(9000000, 1.3, 0.6)

# %%
t = range(0, 100)
plt.plot(t, s, label='susceptable')
plt.plot(t, i, label='infected')
plt.plot(t, r, label='recovered')
plt.legend()
plt.show()
print("peak infections of {0} at day {1}".format(max(i), np.argmax(i)))
# Out:
# peak infections of 1299225.7934789814 at day 19

# %%
# Out:
# peak infections of 30861018.642755907 at day 21
